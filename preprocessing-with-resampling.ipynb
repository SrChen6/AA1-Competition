# %% [markdown]
# # Data preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.precision', 3)

# %%
# Extra imports
from pandas import read_csv
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import LocalOutlierFactor
from sklearn.decomposition import PCA
from sklearn import preprocessing
from pandas.plotting import scatter_matrix
from scipy.stats import boxcox, norm
from statsmodels.genmod.generalized_linear_model import GLM

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(42)  # The solution.

# %% [markdown]
# ## Reading CSV

# %%
raw_ILDS = read_csv("train_features_ILDS.csv", delimiter=',')
raw_ILDS.columns = ['Age', 'Female', 'TB', 'DB', 'Alkphos', 'Sgpt', 
                    'Sgot', 'TP', 'ALB', 'AR']
raw_ILDS['target'] = read_csv("train_labels_ILDS.csv", delimiter=',')
raw_ILDS['Female'] = raw_ILDS['Female'].astype('category')
raw_ILDS['target'] = raw_ILDS['target'].astype('category')

raw_ILDS.shape #tamany
# Out:
# (462, 11)

# %% [markdown]
# - Bilirubin (TB & DB): product of the degradation of hemoglobin. It should be processed by the liver and make it water-soluble to be expelled from the body. Direct Bilirubin is the Bilirubin processed by the liver, the Indirect one is the Bilirubin unprocessed, and the total is the sum of the two.
# - Alkaline Phosphotase (Alkphos): enzime that breaks down phosphate groups. It is everywhere, but more concentrated in the liver and bones. Liver damages can lead to an increased release of these enzimes.
# - Alamine Aminotransferase (Sgpt): enzime that participates in the metabolism of amino acids. Damages in the liver can lead to an increase of these enzimes.
# - Aspartate Aminotransferase (Sgot): enzime that participates in the metabolism of amino acids (just like Sgpt). Liver, heart or Muscle injuries can lead to an increase of concentration of these enzimes.
# - Total proteins (TP): total of proteins in blood. Problems in liver or kidneys may lead to a decrease of this concentration.
# - Albumin (ALB): keeps fluids inside blood vessels and transports substances. Problems in the liver may decrease its concentration, as this proteins is exclusively procused by the Liver.
# - Albumin to Globulin (A/R): low ratio may indicate liver problems.

# %% [markdown]
# # 1. Basic inspection of the dataset

# %% [markdown]
# At first glance the dataset does not have any problems, as there are no explicit missing values (but we don't know if there are imputed missing values in this dataset).
#
# It is worrying that **the number of sick patients is higher than the number of healthy patients** in this dataset. The number of male individuals is much higher than that of female individuals, too.
#
# So we need to **apply resampling** to compensate, at least, **for the lack of balance between sick and healthy patients**.

# %%
raw_ILDS.head()
# Out:
#    Age Female   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AR target
# 0   48      0  4.5  2.3      282    13    74  7.0  2.4  0.52      0
# 1   39      0  1.9  0.9      180    42    62  7.4  4.3  1.38      0
# 2   23      0  1.0  0.3      212    41    80  6.2  3.1  1.00      0
# 3   42      1  0.7  0.2      152    35    81  6.2  3.2  1.06      0
# 4   52      1  0.6  0.1      194    10    12  6.9  3.3  0.90      1

# %%
raw_ILDS.describe()
# Out:
#            Age       TB       DB   Alkphos      Sgpt      Sgot       TP  \
# count  462.000  462.000  462.000   462.000   462.000   462.000  462.000
# mean    44.892    3.277    1.445   279.714    73.952    94.571    6.421
# std     16.325    6.121    2.678   211.487   164.499   202.027    1.053
# min      4.000    0.400    0.100    75.000    10.000    11.000    2.700
# 25%     33.000    0.800    0.200   176.000    23.000    25.000    5.700
# 50%     45.000    1.000    0.300   208.000    34.000    41.000    6.500
# 75%     57.750    2.675    1.275   290.000    59.750    82.750    7.100
# max     90.000   75.000   18.300  1630.000  2000.000  2946.000    9.500
#
#            ALB       AR
# count  462.000  462.000
# mean     3.108    0.942
# std      0.793    0.318
# min      0.900    0.300
# 25%      2.500    0.700
# 50%      3.100    0.910
# 75%      3.700    1.100
# max      5.500    2.800

# %%
raw_ILDS['Female'].value_counts()
# Out:
# Female
# 0    350
# 1    112
# Name: count, dtype: int64

# %%
raw_ILDS[raw_ILDS['Female'] == 1]['target'].value_counts()
# Out:
# target
# 0    74
# 1    38
# Name: count, dtype: int64

# %%
raw_ILDS[raw_ILDS['Female'] == 0]['target'].value_counts()
# Out:
# target
# 0    256
# 1     94
# Name: count, dtype: int64

# %% [markdown]
# We are now going to build scatterplots of all of our variables. At first glance there is no clear separation between sick and healthy patients, but this may be because we are looking at the dataset from the "wrong perspective".

# %%
sns.pairplot(raw_ILDS, hue = "target")

# %%
sns.pairplot(raw_ILDS, hue = "Female")

# %% [markdown]
# We can try to appy PCA to this dataset, which ends up being successful as 2 dimensions captures more than 95% of the total variance of the whole dataset. The problem is that when visualizing the dataset in the 2 most important dimensions, **there is still no clear difference between a sick and healthy patient**.
#
# But this was still a very useful analysis, because we have identified **4 individuals in our dataset which are clearly outliers**. We can easily distinguish them because they are far away from the others. We need to remove these outliers as they might be clouding our PCA analysis (or, in general, hindering our data analysis).

# %%
raw_numILDS = raw_ILDS.drop(columns = ["Female", "target"])
corr = raw_numILDS.corr()
corr.style.background_gradient(cmap='RdBu')
# Out:
# <style type="text/css">
# #T_bc455_row0_col0, #T_bc455_row1_col1, #T_bc455_row2_col2, #T_bc455_row3_col3, #T_bc455_row4_col4, #T_bc455_row5_col5, #T_bc455_row6_col6, #T_bc455_row7_col7, #T_bc455_row8_col8 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_bc455_row0_col1, #T_bc455_row4_col7, #T_bc455_row5_col8 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
# }
# #T_bc455_row0_col2 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_bc455_row0_col3 {
#   background-color: #f09c7b;
#   color: #000000;
# }
# #T_bc455_row0_col4, #T_bc455_row0_col5, #T_bc455_row0_col6, #T_bc455_row0_col7, #T_bc455_row3_col8, #T_bc455_row7_col0, #T_bc455_row7_col1, #T_bc455_row7_col2, #T_bc455_row7_col5, #T_bc455_row8_col1, #T_bc455_row8_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_bc455_row0_col8, #T_bc455_row1_col8, #T_bc455_row2_col7, #T_bc455_row2_col8, #T_bc455_row3_col7, #T_bc455_row7_col4 {
#   background-color: #900d26;
#   color: #f1f1f1;
# }
# #T_bc455_row1_col0 {
#   background-color: #e48066;
#   color: #f1f1f1;
# }
# #T_bc455_row1_col2, #T_bc455_row2_col1 {
#   background-color: #2870b1;
#   color: #f1f1f1;
# }
# #T_bc455_row1_col3 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_bc455_row1_col4 {
#   background-color: #ea8e70;
#   color: #f1f1f1;
# }
# #T_bc455_row1_col5 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_bc455_row1_col6 {
#   background-color: #c43b3c;
#   color: #f1f1f1;
# }
# #T_bc455_row1_col7, #T_bc455_row8_col0 {
#   background-color: #991027;
#   color: #f1f1f1;
# }
# #T_bc455_row2_col0 {
#   background-color: #e27b62;
#   color: #f1f1f1;
# }
# #T_bc455_row2_col3 {
#   background-color: #fcdfcf;
#   color: #000000;
# }
# #T_bc455_row2_col4 {
#   background-color: #ef9979;
#   color: #000000;
# }
# #T_bc455_row2_col5 {
#   background-color: #f8bda1;
#   color: #000000;
# }
# #T_bc455_row2_col6 {
#   background-color: #c53e3d;
#   color: #f1f1f1;
# }
# #T_bc455_row3_col0 {
#   background-color: #f2a17f;
#   color: #000000;
# }
# #T_bc455_row3_col1 {
#   background-color: #f9c6ac;
#   color: #000000;
# }
# #T_bc455_row3_col2, #T_bc455_row5_col1 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_bc455_row3_col4 {
#   background-color: #d25849;
#   color: #f1f1f1;
# }
# #T_bc455_row3_col5 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
# }
# #T_bc455_row3_col6 {
#   background-color: #b61f2e;
#   color: #f1f1f1;
# }
# #T_bc455_row4_col0, #T_bc455_row6_col2, #T_bc455_row6_col3 {
#   background-color: #c2383a;
#   color: #f1f1f1;
# }
# #T_bc455_row4_col1 {
#   background-color: #f6b394;
#   color: #000000;
# }
# #T_bc455_row4_col2 {
#   background-color: #f9c2a7;
#   color: #000000;
# }
# #T_bc455_row4_col3 {
#   background-color: #f3a481;
#   color: #000000;
# }
# #T_bc455_row4_col5 {
#   background-color: #1c5c9f;
#   color: #f1f1f1;
# }
# #T_bc455_row4_col6 {
#   background-color: #ba2832;
#   color: #f1f1f1;
# }
# #T_bc455_row4_col8 {
#   background-color: #dd7059;
#   color: #f1f1f1;
# }
# #T_bc455_row5_col0, #T_bc455_row5_col7 {
#   background-color: #c84440;
#   color: #f1f1f1;
# }
# #T_bc455_row5_col2 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_bc455_row5_col3 {
#   background-color: #f4a683;
#   color: #000000;
# }
# #T_bc455_row5_col4 {
#   background-color: #1b5a9c;
#   color: #f1f1f1;
# }
# #T_bc455_row5_col6 {
#   background-color: #bb2a34;
#   color: #f1f1f1;
# }
# #T_bc455_row6_col0, #T_bc455_row7_col3, #T_bc455_row8_col5 {
#   background-color: #8a0b25;
#   color: #f1f1f1;
# }
# #T_bc455_row6_col1 {
#   background-color: #be3036;
#   color: #f1f1f1;
# }
# #T_bc455_row6_col4 {
#   background-color: #790622;
#   color: #f1f1f1;
# }
# #T_bc455_row6_col5, #T_bc455_row8_col2 {
#   background-color: #6d0220;
#   color: #f1f1f1;
# }
# #T_bc455_row6_col7 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_bc455_row6_col8 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_bc455_row7_col6 {
#   background-color: #3681ba;
#   color: #f1f1f1;
# }
# #T_bc455_row7_col8 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_bc455_row8_col4 {
#   background-color: #b3192c;
#   color: #f1f1f1;
# }
# #T_bc455_row8_col6 {
#   background-color: #fdddcb;
#   color: #000000;
# }
# #T_bc455_row8_col7 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc455">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc455_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_bc455_level0_col1" class="col_heading level0 col1" >TB</th>
#       <th id="T_bc455_level0_col2" class="col_heading level0 col2" >DB</th>
#       <th id="T_bc455_level0_col3" class="col_heading level0 col3" >Alkphos</th>
#       <th id="T_bc455_level0_col4" class="col_heading level0 col4" >Sgpt</th>
#       <th id="T_bc455_level0_col5" class="col_heading level0 col5" >Sgot</th>
#       <th id="T_bc455_level0_col6" class="col_heading level0 col6" >TP</th>
#       <th id="T_bc455_level0_col7" class="col_heading level0 col7" >ALB</th>
#       <th id="T_bc455_level0_col8" class="col_heading level0 col8" >AR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc455_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_bc455_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bc455_row0_col1" class="data row0 col1" >0.024366</td>
#       <td id="T_bc455_row0_col2" class="data row0 col2" >0.017433</td>
#       <td id="T_bc455_row0_col3" class="data row0 col3" >0.085129</td>
#       <td id="T_bc455_row0_col4" class="data row0 col4" >-0.107461</td>
#       <td id="T_bc455_row0_col5" class="data row0 col5" >-0.084081</td>
#       <td id="T_bc455_row0_col6" class="data row0 col6" >-0.231473</td>
#       <td id="T_bc455_row0_col7" class="data row0 col7" >-0.295335</td>
#       <td id="T_bc455_row0_col8" class="data row0 col8" >-0.206833</td>
#     </tr>
#     <tr>
#       <th id="T_bc455_level0_row1" class="row_heading level0 row1" >TB</th>
#       <td id="T_bc455_row1_col0" class="data row1 col0" >0.024366</td>
#       <td id="T_bc455_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bc455_row1_col2" class="data row1 col2" >0.850755</td>
#       <td id="T_bc455_row1_col3" class="data row1 col3" >0.230161</td>
#       <td id="T_bc455_row1_col4" class="data row1 col4" >0.186874</td>
#       <td id="T_bc455_row1_col5" class="data row1 col5" >0.259254</td>
#       <td id="T_bc455_row1_col6" class="data row1 col6" >-0.045033</td>
#       <td id="T_bc455_row1_col7" class="data row1 col7" >-0.208625</td>
#       <td id="T_bc455_row1_col8" class="data row1 col8" >-0.208371</td>
#     </tr>
#     <tr>
#       <th id="T_bc455_level0_row2" class="row_heading level0 row2" >DB</th>
#       <td id="T_bc455_row2_col0" class="data row2 col0" >0.017433</td>
#       <td id="T_bc455_row2_col1" class="data row2 col1" >0.850755</td>
#       <td id="T_bc455_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bc455_row2_col3" class="data row2 col3" >0.254492</td>
#       <td id="T_bc455_row2_col4" class="data row2 col4" >0.208011</td>
#       <td id="T_bc455_row2_col5" class="data row2 col5" >0.289259</td>
#       <td id="T_bc455_row2_col6" class="data row2 col6" >-0.043177</td>
#       <td id="T_bc455_row2_col7" class="data row2 col7" >-0.222333</td>
#       <td id="T_bc455_row2_col8" class="data row2 col8" >-0.208860</td>
#     </tr>
#     <tr>
#       <th id="T_bc455_level0_row3" class="row_heading level0 row3" >Alkphos</th>
#       <td id="T_bc455_row3_col0" class="data row3 col0" >0.085129</td>
#       <td id="T_bc455_row3_col1" class="data row3 col1" >0.230161</td>
#       <td id="T_bc455_row3_col2" class="data row3 col2" >0.254492</td>
#       <td id="T_bc455_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_bc455_row3_col4" class="data row3 col4" >0.102331</td>
#       <td id="T_bc455_row3_col5" class="data row3 col5" >0.106254</td>
#       <td id="T_bc455_row3_col6" class="data row3 col6" >-0.093445</td>
#       <td id="T_bc455_row3_col7" class="data row3 col7" >-0.219599</td>
#       <td id="T_bc455_row3_col8" class="data row3 col8" >-0.279894</td>
#     </tr>
#     <tr>
#       <th id="T_bc455_level0_row4" class="row_heading level0 row4" >Sgpt</th>
#       <td id="T_bc455_row4_col0" class="data row4 col0" >-0.107461</td>
#       <td id="T_bc455_row4_col1" class="data row4 col1" >0.186874</td>

# %%
eigs, U = np.linalg.eig(corr) 
X_pca = raw_numILDS @ U

print(eigs)
print(X_pca.shape)
# Out:
# [2.84731721 2.08367591 1.42377151 0.83860588 0.88428466 0.64125701
#  0.04482713 0.08658912 0.14967158]
# (462, 9)

# %%
x = X_pca.loc[:, 0]
y = X_pca.loc[:, 1]
z = X_pca.loc[:, 2]

plt.figure(figsize = (6, 4))
_ = plt.scatter(x = x, y = y, c = raw_ILDS['target'], cmap = "RdBu")

# %%
fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(projection = '3d')
ax.scatter(xs = x, ys = y, zs = z, c = raw_ILDS['target'], cmap = "RdBu")

_ = ax.set_xlabel("2nd dim")
_ = ax.set_ylabel("1st dim")
_ = ax.set_zlabel("3rd dim")

# %% [markdown]
# # 2. Removing outliers
#
# ### General outliers
#
# From PCA analysis, we have decided to remove 4 individuals which are clearly outliers.

# %%
outliers = X_pca.loc[:, 0] < -600
outliers.value_counts()
# Out:
# 0
# False    458
# True       4
# Name: count, dtype: int64

# %%
no_outs_ILDS = raw_ILDS[np.logical_not(outliers)]
raw_ILDS.describe()
# Out:
#            Age       TB       DB   Alkphos      Sgpt      Sgot       TP  \
# count  462.000  462.000  462.000   462.000   462.000   462.000  462.000
# mean    44.892    3.277    1.445   279.714    73.952    94.571    6.421
# std     16.325    6.121    2.678   211.487   164.499   202.027    1.053
# min      4.000    0.400    0.100    75.000    10.000    11.000    2.700
# 25%     33.000    0.800    0.200   176.000    23.000    25.000    5.700
# 50%     45.000    1.000    0.300   208.000    34.000    41.000    6.500
# 75%     57.750    2.675    1.275   290.000    59.750    82.750    7.100
# max     90.000   75.000   18.300  1630.000  2000.000  2946.000    9.500
#
#            ALB       AR
# count  462.000  462.000
# mean     3.108    0.942
# std      0.793    0.318
# min      0.900    0.300
# 25%      2.500    0.700
# 50%      3.100    0.910
# 75%      3.700    1.100
# max      5.500    2.800

# %%
no_outs_ILDS.describe()
# Out:
#            Age       TB       DB  Alkphos     Sgpt     Sgot       TP      ALB  \
# count  458.000  458.000  458.000   458.00  458.000  458.000  458.000  458.000
# mean    45.041    3.182    1.403   277.52   62.000   81.083    6.429    3.112
# std     16.275    5.999    2.623   205.54   95.148  120.842    1.054    0.795
# min      4.000    0.400    0.100    75.00   10.000   11.000    2.700    0.900
# 25%     33.000    0.800    0.200   176.00   23.000   25.000    5.700    2.500
# 50%     45.000    1.000    0.300   208.00   33.500   41.000    6.500    3.100
# 75%     58.000    2.600    1.200   290.00   58.750   80.000    7.100    3.700
# max     90.000   75.000   18.300  1630.00  875.000  850.000    9.500    5.500
#
#             AR
# count  458.000
# mean     0.942
# std      0.318
# min      0.300
# 25%      0.700
# 50%      0.900
# 75%      1.100
# max      2.800

# %% [markdown]
# We now apply PCA again. Once again, there is no clear distinction between what a sick and healthy patient should be as the clouds of points are very near each other. But it is a good starting point because we have removed the 4 most prominent outliers, which could have been problematic.
#
# **NOTA PEL HAO: Observa el plot 2D de les dues primeres dimensions. Veus que hi ha un outlier de pacients sans a la dreta del tot? Si volem usar un k-nearest neighbors o potser fins i tot un SVM amb algun kernel estrany, la funció de probabilitat pot ser més alta allà del que hauria de ser o es pot liar el SVM... Encara pitjor, és possible que en el resampling, si el féssim automàtic, apareguessin punts allà que no tenen sentit. Tú que penses? L'hem d'eliminar?**
#
# **I després podriem considerar eliminar algun punt més, però potser seria passar-se? No sé...**

# %%
no_outs_numILDS = no_outs_ILDS.drop(columns = ["Female", "target"])
corr = no_outs_numILDS.corr()
corr.style.background_gradient(cmap='RdBu')
# Out:
# <style type="text/css">
# #T_34ed7_row0_col0, #T_34ed7_row1_col1, #T_34ed7_row2_col2, #T_34ed7_row3_col3, #T_34ed7_row4_col4, #T_34ed7_row5_col5, #T_34ed7_row6_col6, #T_34ed7_row7_col7, #T_34ed7_row8_col8 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_34ed7_row0_col1, #T_34ed7_row0_col2 {
#   background-color: #da6853;
#   color: #f1f1f1;
# }
# #T_34ed7_row0_col3 {
#   background-color: #f4a683;
#   color: #000000;
# }
# #T_34ed7_row0_col4, #T_34ed7_row0_col6, #T_34ed7_row0_col7, #T_34ed7_row3_col8, #T_34ed7_row7_col0, #T_34ed7_row7_col1, #T_34ed7_row7_col2, #T_34ed7_row7_col5, #T_34ed7_row8_col1, #T_34ed7_row8_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_34ed7_row0_col5, #T_34ed7_row3_col7 {
#   background-color: #9c1127;
#   color: #f1f1f1;
# }
# #T_34ed7_row0_col8 {
#   background-color: #840924;
#   color: #f1f1f1;
# }
# #T_34ed7_row1_col0 {
#   background-color: #ec9374;
#   color: #f1f1f1;
# }
# #T_34ed7_row1_col2, #T_34ed7_row2_col1 {
#   background-color: #2b73b3;
#   color: #f1f1f1;
# }
# #T_34ed7_row1_col3 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_34ed7_row1_col4, #T_34ed7_row5_col0 {
#   background-color: #d86551;
#   color: #f1f1f1;
# }
# #T_34ed7_row1_col5, #T_34ed7_row3_col0, #T_34ed7_row4_col2 {
#   background-color: #f6b191;
#   color: #000000;
# }
# #T_34ed7_row1_col6, #T_34ed7_row2_col6 {
#   background-color: #c84440;
#   color: #f1f1f1;
# }
# #T_34ed7_row1_col7 {
#   background-color: #a21328;
#   color: #f1f1f1;
# }
# #T_34ed7_row1_col8, #T_34ed7_row6_col0 {
#   background-color: #8d0c25;
#   color: #f1f1f1;
# }
# #T_34ed7_row2_col0 {
#   background-color: #ea8e70;
#   color: #f1f1f1;
# }
# #T_34ed7_row2_col3 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_34ed7_row2_col4 {
#   background-color: #e17860;
#   color: #f1f1f1;
# }
# #T_34ed7_row2_col5 {
#   background-color: #f9c4a9;
#   color: #000000;
# }
# #T_34ed7_row2_col7, #T_34ed7_row8_col0 {
#   background-color: #991027;
#   color: #f1f1f1;
# }
# #T_34ed7_row2_col8 {
#   background-color: #8a0b25;
#   color: #f1f1f1;
# }
# #T_34ed7_row3_col1 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_34ed7_row3_col2 {
#   background-color: #f9c6ac;
#   color: #000000;
# }
# #T_34ed7_row3_col4 {
#   background-color: #cf5246;
#   color: #f1f1f1;
# }
# #T_34ed7_row3_col5 {
#   background-color: #d7634f;
#   color: #f1f1f1;
# }
# #T_34ed7_row3_col6 {
#   background-color: #b72230;
#   color: #f1f1f1;
# }
# #T_34ed7_row4_col0 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
# }
# #T_34ed7_row4_col1 {
#   background-color: #f19e7d;
#   color: #000000;
# }
# #T_34ed7_row4_col3 {
#   background-color: #f5a886;
#   color: #000000;
# }
# #T_34ed7_row4_col5 {
#   background-color: #2f79b5;
#   color: #f1f1f1;
# }
# #T_34ed7_row4_col6 {
#   background-color: #cb4942;
#   color: #f1f1f1;
# }
# #T_34ed7_row4_col7 {
#   background-color: #d6604d;
#   color: #f1f1f1;
# }
# #T_34ed7_row4_col8 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_34ed7_row5_col1 {
#   background-color: #facab1;
#   color: #000000;
# }
# #T_34ed7_row5_col2 {
#   background-color: #fcdecd;
#   color: #000000;
# }
# #T_34ed7_row5_col3 {
#   background-color: #f3a481;
#   color: #000000;
# }
# #T_34ed7_row5_col4 {
#   background-color: #307ab6;
#   color: #f1f1f1;
# }
# #T_34ed7_row5_col6 {
#   background-color: #c6413e;
#   color: #f1f1f1;
# }
# #T_34ed7_row5_col7, #T_34ed7_row6_col2 {
#   background-color: #c2383a;
#   color: #f1f1f1;
# }
# #T_34ed7_row5_col8 {
#   background-color: #bb2a34;
#   color: #f1f1f1;
# }
# #T_34ed7_row6_col1, #T_34ed7_row6_col3 {
#   background-color: #bf3338;
#   color: #f1f1f1;
# }
# #T_34ed7_row6_col4, #T_34ed7_row7_col3 {
#   background-color: #870a24;
#   color: #f1f1f1;
# }
# #T_34ed7_row6_col5 {
#   background-color: #960f27;
#   color: #f1f1f1;
# }
# #T_34ed7_row6_col7 {
#   background-color: #327cb7;
#   color: #f1f1f1;
# }
# #T_34ed7_row6_col8 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_34ed7_row7_col4 {
#   background-color: #7f0823;
#   color: #f1f1f1;
# }
# #T_34ed7_row7_col6 {
#   background-color: #3480b9;
#   color: #f1f1f1;
# }
# #T_34ed7_row7_col8 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_34ed7_row8_col2 {
#   background-color: #6d0220;
#   color: #f1f1f1;
# }
# #T_34ed7_row8_col4 {
#   background-color: #730421;
#   color: #f1f1f1;
# }
# #T_34ed7_row8_col5 {
#   background-color: #6a011f;
#   color: #f1f1f1;
# }
# #T_34ed7_row8_col6 {
#   background-color: #fcdfcf;
#   color: #000000;
# }
# #T_34ed7_row8_col7 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_34ed7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ed7_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_34ed7_level0_col1" class="col_heading level0 col1" >TB</th>
#       <th id="T_34ed7_level0_col2" class="col_heading level0 col2" >DB</th>
#       <th id="T_34ed7_level0_col3" class="col_heading level0 col3" >Alkphos</th>
#       <th id="T_34ed7_level0_col4" class="col_heading level0 col4" >Sgpt</th>
#       <th id="T_34ed7_level0_col5" class="col_heading level0 col5" >Sgot</th>
#       <th id="T_34ed7_level0_col6" class="col_heading level0 col6" >TP</th>
#       <th id="T_34ed7_level0_col7" class="col_heading level0 col7" >ALB</th>
#       <th id="T_34ed7_level0_col8" class="col_heading level0 col8" >AR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ed7_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_34ed7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_34ed7_row0_col1" class="data row0 col1" >0.051752</td>
#       <td id="T_34ed7_row0_col2" class="data row0 col2" >0.044799</td>
#       <td id="T_34ed7_row0_col3" class="data row0 col3" >0.116109</td>
#       <td id="T_34ed7_row0_col4" class="data row0 col4" >-0.079398</td>
#       <td id="T_34ed7_row0_col5" class="data row0 col5" >-0.033720</td>
#       <td id="T_34ed7_row0_col6" class="data row0 col6" >-0.239132</td>
#       <td id="T_34ed7_row0_col7" class="data row0 col7" >-0.305933</td>
#       <td id="T_34ed7_row0_col8" class="data row0 col8" >-0.215281</td>
#     </tr>
#     <tr>
#       <th id="T_34ed7_level0_row1" class="row_heading level0 row1" >TB</th>
#       <td id="T_34ed7_row1_col0" class="data row1 col0" >0.051752</td>
#       <td id="T_34ed7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_34ed7_row1_col2" class="data row1 col2" >0.843199</td>
#       <td id="T_34ed7_row1_col3" class="data row1 col3" >0.196431</td>
#       <td id="T_34ed7_row1_col4" class="data row1 col4" >0.146558</td>
#       <td id="T_34ed7_row1_col5" class="data row1 col5" >0.242608</td>
#       <td id="T_34ed7_row1_col6" class="data row1 col6" >-0.038748</td>
#       <td id="T_34ed7_row1_col7" class="data row1 col7" >-0.201472</td>
#       <td id="T_34ed7_row1_col8" class="data row1 col8" >-0.203790</td>
#     </tr>
#     <tr>
#       <th id="T_34ed7_level0_row2" class="row_heading level0 row2" >DB</th>
#       <td id="T_34ed7_row2_col0" class="data row2 col0" >0.044799</td>
#       <td id="T_34ed7_row2_col1" class="data row2 col1" >0.843199</td>
#       <td id="T_34ed7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_34ed7_row2_col3" class="data row2 col3" >0.223041</td>
#       <td id="T_34ed7_row2_col4" class="data row2 col4" >0.176549</td>
#       <td id="T_34ed7_row2_col5" class="data row2 col5" >0.283507</td>
#       <td id="T_34ed7_row2_col6" class="data row2 col6" >-0.036740</td>
#       <td id="T_34ed7_row2_col7" class="data row2 col7" >-0.216005</td>
#       <td id="T_34ed7_row2_col8" class="data row2 col8" >-0.205004</td>
#     </tr>
#     <tr>
#       <th id="T_34ed7_level0_row3" class="row_heading level0 row3" >Alkphos</th>
#       <td id="T_34ed7_row3_col0" class="data row3 col0" >0.116109</td>
#       <td id="T_34ed7_row3_col1" class="data row3 col1" >0.196431</td>
#       <td id="T_34ed7_row3_col2" class="data row3 col2" >0.223041</td>
#       <td id="T_34ed7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_34ed7_row3_col4" class="data row3 col4" >0.118016</td>
#       <td id="T_34ed7_row3_col5" class="data row3 col5" >0.112488</td>
#       <td id="T_34ed7_row3_col6" class="data row3 col6" >-0.094522</td>
#       <td id="T_34ed7_row3_col7" class="data row3 col7" >-0.210520</td>
#       <td id="T_34ed7_row3_col8" class="data row3 col8" >-0.268

# %%
eigs, U = np.linalg.eig(corr) 
X_pca = no_outs_numILDS @ U

print(eigs)
print(X_pca.shape)
# Out:
# [2.83737052 1.99789175 1.41053143 0.91236037 0.83475683 0.65434967
#  0.04446727 0.14618232 0.16208983]
# (458, 9)

# %%
x = X_pca.loc[:, 0]
y = X_pca.loc[:, 1]
z = X_pca.loc[:, 2]

plt.figure(figsize = (6, 4))
plt.scatter(x = x, y = y, c = no_outs_ILDS['target'], cmap = "RdBu")

# %%
fig = plt.figure(figsize = (7, 8))
ax = fig.add_subplot(projection = '3d')
ax.scatter(xs = -y, ys = x, zs = z, c = no_outs_ILDS['target'], cmap = "RdBu")

_ = ax.set_xlabel("2nd dim")
_ = ax.set_ylabel("1st dim")
_ = ax.set_zlabel("3rd dim")

# %%
(no_outs_ILDS['TB'] < no_outs_ILDS['DB']).value_counts()
# Out:
# False    457
# True       1
# Name: count, dtype: int64

# %% [markdown]
# ## Individual analysis of each variable
#
# We will take a look at every variable individually. We will attempt to find outliers for those values and if necessary we will eliminate them. We will also consider whether we need to apply transformations to them.
#
# Transformations needed (generally BoxCox):
# - Total and direct bilirubin
# - Alkaline Phosphotase
# - Alamine Aminotransferase
# - Aspartate Aminotransferase
#
# Outliers found right now:
# - TB: Very important outlier with value 75. Could be eliminated.
# - DB: We would need to apply a suitable Box-Cox transformation before analyzing whether there are plausible outliers or not...
# - Alkphos: Plausible outliers at the far right end.
# - Sgpt: Notable outlier at the far right.
# - Proteins: Far left.
# - AR: Far right.

# %%
def histbox (data, column: str, n_bins: int = 10) -> None:
    fig, axes = plt.subplots(1, 2, gridspec_kw = {'width_ratios': [1, 4]}, figsize=(9,4))
    sns.boxplot(data = data, x = 'target', y = column, hue = 'target', ax = axes[0])
    
    sick = data[data["target"] == 0]
    healthy = data[data["target"] == 1]
    mean_sick = np.mean(sick[column])
    mean_healthy = np.mean(healthy[column])
    std_sick = np.std(sick[column])
    std_healthy = np.std(healthy[column])
    prop_sick = len(sick) / len(data)
    prop_healthy = len(healthy) / len(data)
    
    x = np.linspace(np.min(sick[column]), np.max(sick[column]), num = 500)
    y = np.linspace(np.min(healthy[column]), np.max(healthy[column]), num = 500)
    ax = sns.histplot(data = data, x = column, hue = 'target', ax = axes[1],
                      bins = n_bins, stat = "density")
    ax.plot(x, norm.pdf(x, loc = mean_sick, scale = std_sick) * prop_sick)
    ax.plot(y, norm.pdf(y, loc = mean_healthy, scale = std_healthy) * prop_healthy)

# %% [markdown]
# ### Age

# %%
histbox(no_outs_ILDS, "Age", 16)

# %% [markdown]
# ### Total Bilirubin

# %%
histbox(no_outs_ILDS, "TB", 16)

# %%
(no_outs_ILDS.TB < 70).value_counts() # TODO: potser no és un missing value, i realment algú el tenia tan alt?
# Out:
# TB
# True     457
# False      1
# Name: count, dtype: int64

# %%
no_outs_ILDS = no_outs_ILDS[no_outs_ILDS.TB < 70]

# %% [markdown]
# ### Direct Bilirubin

# %%
histbox(no_outs_ILDS, "DB", 16)

# %% [markdown]
# ### Indirect Bilirubin

# %%
no_outs_ILDS["IB"] = no_outs_ILDS["TB"] - no_outs_ILDS["DB"]
histbox(no_outs_ILDS, "IB", 16)

# %%
(no_outs_ILDS.IB < 0).value_counts()
# Out:
# IB
# False    456
# True       1
# Name: count, dtype: int64

# %%
no_outs_ILDS = no_outs_ILDS[no_outs_ILDS.IB >= 0]

# %% [markdown]
# ### Alkaline Phosphotase

# %%
histbox(no_outs_ILDS, "Alkphos", 16) # TODO: Logarithmic també?

# %%
(no_outs_ILDS.Alkphos < 1200).value_counts()
# Out:
# Alkphos
# True     451
# False      5
# Name: count, dtype: int64

# %%
no_outs_ILDS = no_outs_ILDS[no_outs_ILDS.Alkphos < 1200]

# %% [markdown]
# ### Alamine Aminotransferase

# %%
histbox(no_outs_ILDS, "Sgpt", 16) # TODO: Logarithmic també?

# %%
(no_outs_ILDS.Sgpt < 700).value_counts()
# Out:
# Sgpt
# True     448
# False      3
# Name: count, dtype: int64

# %%
no_outs_ILDS = no_outs_ILDS[no_outs_ILDS.Sgpt < 700]

# %% [markdown]
# ### Aspartate Aminotransferase

# %%
histbox(no_outs_ILDS, "Sgot", 16) # TODO: Res sembla una normal :D

# %%
(no_outs_ILDS.Sgot < 700).value_counts()
# Out:
# Sgot
# True     445
# False      3
# Name: count, dtype: int64

# %%
no_outs_ILDS = no_outs_ILDS[no_outs_ILDS.Sgot < 700]

# %% [markdown]
# ### Total Proteins

# %%
histbox(no_outs_ILDS, "TP", 16)

# %% [markdown]
# ### Albumin

# %%
histbox(no_outs_ILDS, "ALB", 16) # Cool

# %%
(no_outs_ILDS.ALB < 5).value_counts()
# Out:
# ALB
# True     442
# False      3
# Name: count, dtype: int64

# %%
no_outs_ILDS = no_outs_ILDS[no_outs_ILDS.ALB < 5]

# %% [markdown]
# ### Albumin and Globulin Ratio

# %%
histbox(no_outs_ILDS, "AR", 16)

# %%
(no_outs_ILDS.AR < 2.2).value_counts()
# Out:
# AR
# True     440
# False      2
# Name: count, dtype: int64

# %%
no_outs_ILDS = no_outs_ILDS[no_outs_ILDS.AR < 2.2]

# %%
print(no_outs_ILDS)
# Out:
#      Age Female   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AR target   IB
# 0     48      0  4.5  2.3      282    13    74  7.0  2.4  0.52      0  2.2
# 1     39      0  1.9  0.9      180    42    62  7.4  4.3  1.38      0  1.0
# 2     23      0  1.0  0.3      212    41    80  6.2  3.1  1.00      0  0.7
# 3     42      1  0.7  0.2      152    35    81  6.2  3.2  1.06      0  0.5
# 4     52      1  0.6  0.1      194    10    12  6.9  3.3  0.90      1  0.5
# ..   ...    ...  ...  ...      ...   ...   ...  ...  ...   ...    ...  ...
# 457   18      0  1.8  0.7      178    35    36  6.8  3.6  1.10      0  1.1
# 458   49      1  0.8  0.2      198    23    20  7.0  4.3  1.50      0  0.6
# 459   51      0  2.2  1.0      610    17    28  7.3  2.6  0.55      0  1.2
# 460   45      0  1.1  0.4       92    91   188  7.2  3.8  1.11      0  0.7
# 461    8      1  0.9  0.2      401    25    58  7.5  3.4  0.80      0  0.7
#
# [440 rows x 12 columns]

# %% [markdown]
# ## Logarithm transformations

# %%
log_ILDS = no_outs_ILDS.drop(columns = ['TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot'])

# %%
log_ILDS['DBratio'] = no_outs_ILDS['DB'] / no_outs_ILDS['TB']
histbox(log_ILDS, "DBratio", 16)

# %% [markdown]
# ### Total Bilirubin

# %%
log_ILDS['TB'] = np.log(no_outs_ILDS['TB'])
histbox(log_ILDS, "TB", 16)

# %% [markdown]
# ### Direct Birilubin

# %%
log_ILDS['DB'] = np.log(no_outs_ILDS['DB'])
histbox(log_ILDS, "DB", 16)

# %%
log_ILDS['IB'] = np.log(no_outs_ILDS['IB'])
histbox(log_ILDS, "IB", 16)

# %% [markdown]
# ### Alkphos

# %%
log_ILDS['Alkphos'] = np.log(no_outs_ILDS['Alkphos'])
histbox(log_ILDS, "Alkphos", 16)

# %% [markdown]
# ### Sgpt

# %%
log_ILDS['Sgpt'] = np.log(no_outs_ILDS['Sgpt'])
histbox(log_ILDS, "Sgpt", 16)

# %% [markdown]
# ### Sgot

# %%
log_ILDS['Sgot'] = np.log(no_outs_ILDS['Sgot'])
histbox(log_ILDS, "Sgot", 16)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# After eliminating outliers from our training dataset, we decide to make the following transformations to our data:
#
# - Creation of new variable DBratio
# - Logarithm transformations on TB, DB, Alkphos, Sgpt and Sgot
# - Standardizing of all of our variables to zero mean and variance 1.
# - Resampling of the minority class ONLY FOR THE TRAIN DATA.
#
# For consistency we use the same scaler for the train and test data. We train a scaler from our train data and use it on the test data.

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTENC, SVMSMOTE, ADASYN

def preprocessing (data: pd.DataFrame, scaler: StandardScaler | None = None,
                   train_data: bool = False):
    # New variables
    new_data = data.drop(columns = ['TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot'])
    new_data['DBratio'] = data['TB'] / data['DB']
    new_data['TB'] = np.log(data['TB'])
    new_data['DB'] = np.log(data['DB'])
    new_data['Alkphos'] = np.log(data['Alkphos'])
    new_data['Sgpt'] = np.log(data['Sgpt'])
    new_data['Sgot'] = np.log(data['Sgot'])
    # Scaling
    if train_data:
        numerical_vars = new_data.drop(columns = ["Female", "target"])
    else:
        numerical_vars = new_data.drop(columns = ["Female"])
    if scaler is None:
        scaler = StandardScaler()
        numerical_vars = scaler.fit_transform(numerical_vars)
    else:
        numerical_vars = scaler.transform(numerical_vars)
    result = pd.DataFrame(numerical_vars)
    new_data.index = result.index
    result['Female'] = new_data['Female']
    result.columns = ['Age', 'TP', 'ALB', 'AR', 'DBratio', 'logTB', 'logDB', 'logAlkphos', 'logSgpt', 
                     'logSgot', 'Female']
    # Resampling (only for train_data)
    if train_data:
        smotenc = SMOTENC(sampling_strategy = "minority", random_state = 42,
                          categorical_features = ["Female"])
        X_resampled, y_resampled = smotenc.fit_resample(result, new_data['target'])
        result = X_resampled
        result['Target'] = y_resampled
#     if train_data:
#         adasyn = ADASYN(sampling_strategy = "minority", random_state = 42)
#         X_resampled, y_resampled = adasyn.fit_resample(result, new_data['target'])
#         result = X_resampled
#         result['Target'] = y_resampled
#     if train_data:
#         adasyn = SVMSMOTE(sampling_strategy = "minority", random_state = 42)
#         X_resampled, y_resampled = adasyn.fit_resample(result, new_data['target'])
#         result = X_resampled
#         result['Target'] = y_resampled
    # Return
    return result, scaler
    
if "IB" in no_outs_ILDS.columns:
    no_outs_ILDS = no_outs_ILDS.drop(columns = ["IB"])
    
test_data = read_csv("test_data_ILDS.csv", delimiter=',', header=None)
test_data.columns = ['Age', 'Female', 'TB', 'DB', 'Alkphos', 'Sgpt', 
                    'Sgot', 'TP', 'ALB', 'AR']
test_data['Female'] = test_data['Female'].astype('category')

log_ILDS_train, scaler = preprocessing(no_outs_ILDS, train_data = True)
log_ILDS_test_X, _ = preprocessing(test_data, scaler)

print(log_ILDS_train)
# Out:
#        Age     TP    ALB     AR  DBratio  logTB  logDB  logAlkphos  logSgpt  \
# 0    0.180  0.553 -0.911 -1.419   -1.020  1.113  1.204       0.410   -1.447
# 1   -0.370  0.937  1.534  1.523   -0.907  0.229  0.474      -0.571    0.121
# 2   -1.346 -0.216 -0.011  0.223   -0.010 -0.429 -0.381      -0.213    0.088
# 3   -0.186 -0.216  0.118  0.428    0.112 -0.795 -0.697      -0.941   -0.123
# 4    0.424  0.457  0.247 -0.120    1.947 -0.953 -1.236      -0.407   -1.798
# ..     ...    ...    ...    ...      ...    ...    ...         ...      ...
# 615 -0.459 -0.657 -0.099 -0.408   -0.771  0.492  0.613       1.092    0.532
# 616 -1.636  0.624  0.954  0.855    0.021 -0.730 -0.618      -0.929   -1.012
# 617 -0.953  1.249  1.637  1.061   -1.100  0.286  0.621      -1.229   -0.967
# 618 -1.180  0.306  0.321  0.125   -0.255 -0.953 -0.697      -0.693   -1.341
# 619 -1.167 -0.249 -0.139 -0.120   -0.255 -0.483 -0.341      -0.655   -1.104
#
#      logSgot Female Target
# 0      0.550      0      0
# 1      0.338      0      0
# 2      0.643      0      0
# 3      0.658      1      0
# 4     -1.627      1      1
# ..       ...    ...    ...
# 615    0.450      0      1
# 616   -0.474      1      1
# 617   -0.842      0      1
# 618   -1.354      0      1
# 619   -1.116      0      1
#
# [620 rows x 12 columns]

# %%
print(log_ILDS_train["Target"].value_counts())
# Out:
# Target
# 0    310
# 1    310
# Name: count, dtype: int64

# %%
print(log_ILDS_train.isna().value_counts())
# Out:
# Age    TP     ALB    AR     DBratio  logTB  logDB  logAlkphos  logSgpt  logSgot  Female  Target
# False  False  False  False  False    False  False  False       False    False    False   False     620
# Name: count, dtype: int64

# %% [markdown]
# # Doing a bit of analysis again to avaluate results of oversampling

# %%
sns.pairplot(log_ILDS_train, hue = "Target")

# %%
log_numILDS_train = log_ILDS_train.drop(columns = ["Female", "Target"])
corr = log_numILDS_train.corr()
corr.style.background_gradient(cmap='RdBu')
# Out:
# <style type="text/css">
# #T_26ca5_row0_col0, #T_26ca5_row1_col1, #T_26ca5_row2_col2, #T_26ca5_row3_col3, #T_26ca5_row4_col4, #T_26ca5_row5_col5, #T_26ca5_row6_col6, #T_26ca5_row7_col7, #T_26ca5_row8_col8, #T_26ca5_row9_col9 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_26ca5_row0_col1, #T_26ca5_row0_col2, #T_26ca5_row2_col0, #T_26ca5_row3_col7, #T_26ca5_row4_col5, #T_26ca5_row4_col6, #T_26ca5_row4_col8, #T_26ca5_row4_col9, #T_26ca5_row6_col4, #T_26ca5_row7_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_26ca5_row0_col3 {
#   background-color: #b82531;
#   color: #f1f1f1;
# }
# #T_26ca5_row0_col4 {
#   background-color: #facab1;
#   color: #000000;
# }
# #T_26ca5_row0_col5 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_26ca5_row0_col6, #T_26ca5_row5_col8 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_26ca5_row0_col7, #T_26ca5_row6_col0 {
#   background-color: #f5ac8b;
#   color: #000000;
# }
# #T_26ca5_row0_col8, #T_26ca5_row1_col8 {
#   background-color: #c6413e;
#   color: #f1f1f1;
# }
# #T_26ca5_row0_col9, #T_26ca5_row9_col4 {
#   background-color: #e6866a;
#   color: #f1f1f1;
# }
# #T_26ca5_row1_col0 {
#   background-color: #810823;
#   color: #f1f1f1;
# }
# #T_26ca5_row1_col2 {
#   background-color: #2e77b5;
#   color: #f1f1f1;
# }
# #T_26ca5_row1_col3 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_26ca5_row1_col4, #T_26ca5_row3_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_26ca5_row1_col5 {
#   background-color: #f8bfa4;
#   color: #000000;
# }
# #T_26ca5_row1_col6 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_26ca5_row1_col7 {
#   background-color: #dd7059;
#   color: #f1f1f1;
# }
# #T_26ca5_row1_col9 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
# }
# #T_26ca5_row2_col1 {
#   background-color: #2f79b5;
#   color: #f1f1f1;
# }
# #T_26ca5_row2_col3 {
#   background-color: #3885bc;
#   color: #f1f1f1;
# }
# #T_26ca5_row2_col4, #T_26ca5_row9_col7 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_26ca5_row2_col5 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# #T_26ca5_row2_col6, #T_26ca5_row7_col4 {
#   background-color: #f4a683;
#   color: #000000;
# }
# #T_26ca5_row2_col7 {
#   background-color: #b3192c;
#   color: #f1f1f1;
# }
# #T_26ca5_row2_col8 {
#   background-color: #be3036;
#   color: #f1f1f1;
# }
# #T_26ca5_row2_col9 {
#   background-color: #b41c2d;
#   color: #f1f1f1;
# }
# #T_26ca5_row3_col0 {
#   background-color: #991027;
#   color: #f1f1f1;
# }
# #T_26ca5_row3_col2 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_26ca5_row3_col4 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_26ca5_row3_col5 {
#   background-color: #d6604d;
#   color: #f1f1f1;
# }
# #T_26ca5_row3_col6 {
#   background-color: #eb9172;
#   color: #f1f1f1;
# }
# #T_26ca5_row3_col8 {
#   background-color: #a81529;
#   color: #f1f1f1;
# }
# #T_26ca5_row3_col9, #T_26ca5_row9_col3 {
#   background-color: #ab162a;
#   color: #f1f1f1;
# }
# #T_26ca5_row4_col0 {
#   background-color: #b61f2e;
#   color: #f1f1f1;
# }
# #T_26ca5_row4_col1 {
#   background-color: #d7634f;
#   color: #f1f1f1;
# }
# #T_26ca5_row4_col2, #T_26ca5_row8_col4 {
#   background-color: #f6b191;
#   color: #000000;
# }
# #T_26ca5_row4_col3 {
#   background-color: #fbceb7;
#   color: #000000;
# }
# #T_26ca5_row4_col7 {
#   background-color: #960f27;
#   color: #f1f1f1;
# }
# #T_26ca5_row5_col0 {
#   background-color: #f5a886;
#   color: #000000;
# }
# #T_26ca5_row5_col1 {
#   background-color: #ba2832;
#   color: #f1f1f1;
# }
# #T_26ca5_row5_col2 {
#   background-color: #6a011f;
#   color: #f1f1f1;
# }
# #T_26ca5_row5_col3, #T_26ca5_row6_col2 {
#   background-color: #700320;
#   color: #f1f1f1;
# }
# #T_26ca5_row5_col4 {
#   background-color: #a21328;
#   color: #f1f1f1;
# }
# #T_26ca5_row5_col6, #T_26ca5_row6_col5 {
#   background-color: #08366a;
#   color: #f1f1f1;
# }
# #T_26ca5_row5_col7 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_26ca5_row5_col9 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_26ca5_row6_col1 {
#   background-color: #bb2a34;
#   color: #f1f1f1;
# }
# #T_26ca5_row6_col3 {
#   background-color: #790622;
#   color: #f1f1f1;
# }
# #T_26ca5_row6_col7 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_26ca5_row6_col8 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_26ca5_row6_col9, #T_26ca5_row7_col5 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_26ca5_row7_col0 {
#   background-color: #ee9677;
#   color: #000000;
# }
# #T_26ca5_row7_col1 {
#   background-color: #c53e3d;
#   color: #f1f1f1;
# }
# #T_26ca5_row7_col2 {
#   background-color: #900d26;
#   color: #f1f1f1;
# }
# #T_26ca5_row7_col6 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_26ca5_row7_col8 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_26ca5_row7_col9 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_26ca5_row8_col0 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_26ca5_row8_col1 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_26ca5_row8_col2, #T_26ca5_row8_col3 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
# }
# #T_26ca5_row8_col5 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_26ca5_row8_col6 {
#   background-color: #aed3e6;
#   color: #000000;
# }
# #T_26ca5_row8_col7 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_26ca5_row8_col9 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_26ca5_row9_col0 {
#   background-color: #db6b55;
#   color: #f1f1f1;
# }
# #T_26ca5_row9_col1 {
#   background-color: #b72230;
#   color: #f1f1f1;
# }
# #T_26ca5_row9_col2 {
#   background-color: #930e26;
#   color: #f1f1f1;
# }
# #T_26ca5_row9_col5 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_26ca5_row9_col6 {
#   background-color: #7bb6d6;
#   color: #000000;
# }
# #T_26ca5_row9_col8 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26ca5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26ca5_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_26ca5_level0_col1" class="col_heading level0 col1" >TP</th>
#       <th id="T_26ca5_level0_col2" class="col_heading level0 col2" >ALB</th>
#       <th id="T_26ca5_level0_col3" class="col_heading level0 col3" >AR</th>
#       <th id="T_26ca5_level0_col4" class="col_heading level0 col4" >DBratio</th>
#       <th id="T_26ca5_level0_col5" class="col_heading level0 col5" >logTB</th>
#       <th id="T_26ca5_level0_col6" class="col_heading level0 col6" >logDB</th>
#       <th id="T_26ca5_level0_col7" class="col_heading level0 col7" >logAlkphos</th>
#       <th id="T_26ca5_level0_col8" class="col_heading level0 col8" >logSgpt</th>
#       <th id="T_26ca5_level0_col9" class="col_heading level0 col9" >logSgot</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26ca5_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_26ca5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_26ca5_row0_col1" class="data row0 col1" >-0.216396</td>
#       <td id="T_26ca5_row0_col2" class="data row0 col2" >-0.263426</td>
#       <td id="T_26ca5_row0_col3" class="data row0 col3" >-0.174659</td>
#       <td id="T_26ca5_row0_col4" class="data row0 col4" >-0.123865</td>
#       <td id="T_26ca5_row0_col5" class="data row0 col5" >0.123027</td>
#       <td id="T_26ca5_row0_col6" class="data row0 col6" >0.132866</td>
#       <td id="T_26ca5_row0_col7" class="data row0 col7" >0.088969</td>
#       <td id="T_26ca5_row0_col8" class="data row0 col8" >-0.016649</td>
#       <td id="T_26ca5_row0_col9" class="data row0 col9" >0.012891</td>
#     </tr>
#     <tr>
#       <th id="T_26ca5_level0_row1" class="row_heading level0 row1" >TP</th>
#       <td id="T_26ca5_row1_col0" class="data row1 col0" >-0.216396</td>
#       <td id="T_26ca5_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_26ca5_row1_col2" class="data row1 col2" >0.825708</td>
#       <td id="T_26ca5_row1_col3" class="data row1 col3" >0.341899</td>
#       <td id="T_26ca5_row1_col4" class="data row1 col4" >0.031839</td>
#       <td id="T_26ca5_row1_col5" class="data row1 col5" >-0.068446</td>
#       <td id="T_26ca5_row1_col6" class="data row1 col6" >-0.061913</td>
#       <td id="T_26ca5_row1_col7" class="data row1 col7" >-0.030246</td>
#       <td id="T_26ca5_row1_col8" class="data row1 col8" >-0.013462</td>
#       <td id="T_26ca5_row1_col9" class="data row1 col9" >-0.073995</td>

# %%
eigs, U = np.linalg.eig(corr) 
X_pca = log_numILDS_train @ U

print(eigs)
print(X_pca.shape)
# Out:
# [3.88495993e+00 2.12473200e+00 1.21497115e+00 8.73016309e-01
#  8.08165811e-01 5.18451086e-01 3.43291610e-01 2.09562966e-01
#  2.10825601e-02 1.76657192e-03]
# (620, 10)

# %%
x = X_pca.loc[:, 0]
y = X_pca.loc[:, 2]
z = X_pca.loc[:, 2]

plt.figure(figsize = (6, 4))
plt.scatter(x = x, y = y, c = log_ILDS_train['Target'], cmap = "RdBu")

# %%
fig = plt.figure(figsize = (7, 8))
ax = fig.add_subplot(projection = '3d')
ax.scatter(xs = x, ys = y, zs = z, c = log_ILDS_train['Target'], cmap = "RdBu")

_ = ax.set_xlabel("2nd dim")
_ = ax.set_ylabel("1st dim")
_ = ax.set_zlabel("3rd dim")

# %% [markdown]
# # End. Saving results

# %%
log_ILDS_train.to_csv('log_ILDS_train_X.csv', index = False, header = False)
log_ILDS_test_X.to_csv('log_ILDS_test_X.csv', index = False, header = False)
